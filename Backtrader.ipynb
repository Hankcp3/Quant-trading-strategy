# %% [markdown]
# https://github.com/QuantWorld2022/backtrader

# %% [markdown]
# **Introduce to backtrader**
# --

# %% [markdown]
# 佣金commission fee 0.0003双边/slippage0.0001双边

# %%
import backtrader as bt
import pandas as pd

# %%
data1 = pd.read_excel("IF日收盘价.xlsx")

# %%
data1
# Out:
#       Unnamed: 0       time         code    open   close    high     low  \
# 0              0 2016-01-04  IF9999.CCFX  3640.0  3425.0  3657.4  3415.8
# 1              1 2016-01-05  IF9999.CCFX  3425.0  3408.8  3486.6  3341.0
# 2              2 2016-01-06  IF9999.CCFX  3417.2  3465.0  3501.0  3417.2
# 3              3 2016-01-07  IF9999.CCFX  3430.2  3245.2  3438.8  3238.6
# 4              4 2016-01-08  IF9999.CCFX  3320.4  3309.0  3401.0  3215.4
# ...          ...        ...          ...     ...     ...     ...     ...
# 1456        1456 2021-12-27  IF9999.CCFX  4938.0  4945.0  4963.6  4912.2
# 1457        1457 2021-12-28  IF9999.CCFX  4950.8  4974.6  4993.8  4940.0
# 1458        1458 2021-12-29  IF9999.CCFX  4979.8  4903.0  4981.6  4900.2
# 1459        1459 2021-12-30  IF9999.CCFX  4905.0  4940.0  4964.0  4899.2
# 1460        1460 2021-12-31  IF9999.CCFX  4960.0  4943.0  4973.4  4931.4
#
#       volume        money
# 0      12513  13344117660
# 1      18526  19015809900
# ...
